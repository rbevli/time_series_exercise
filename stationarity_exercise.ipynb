# %% [markdown]
# ### Stationarity Exercise

# %%
# import matplotlib
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd

# import random
import random

# set a random seed
random.seed(5)

# %% [markdown]
# * generate a NON stationary time-series

# %%
n = 600
x = np.arange(n)
y = np.random.rand(n)*x + np.random.normal(size = n)

# %% [markdown]
# * plot the NON stationary series generated above

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# * generate a stationary time-series

# %%
y2= np.random.normal(0, 1, n)

# %% [markdown]
# * plot the stationary series generated above

# %%
plt.plot(x,y2)

# %%
from statsmodels.tsa.stattools import adfuller

# %% [markdown]
# * Create a function `'ADF_Stationarity_Test'` with the input parameters `timeseries` and `significance_level` which:
#     * prints the adfuller test results
#     * prints the conclusion stating whether timeseries is stationary based on the siginificance level (input parameter of function)

# %%
#null hypothesis

def ADF_Stationarity_Test(timeseries, significance_level):
    result = adfuller(timeseries, store = True)
    if result[1]>significance_level:
        print("Pvalue {} is over sig level {}, fail to reject null hypothesis that time series is non stationary.".format(result[1],significance_level))
    else:
        print("Pvalue {} is under sig level {}, reject null hypothesis that timeseries is non stationary.".format(result[1],significance_level))

# %% [markdown]
# * Apply the function `'ADF_Stationarity_Test'` to find out whether the timeseries generated above are stationary.

# %%
ADF_Stationarity_Test(y, 0.05)
# Out:
# Pvalue 0.2940106897427183 is over sig level 0.05, fail to reject null hypothesis that time series is non stationary.

# %%
ADF_Stationarity_Test(y2, 0.05)
# Out:
# Pvalue 0.0 is under sig level 0.05, reject null hypothesis that timeseries is non stationary.

# %% [markdown]
# * Apply a suitable transformation to make the NON stationary time series stationary.

# %%
y2 = np.log(y)
# Out:
# C:\Users\bevli\AppData\Local\Temp/ipykernel_22112/933181766.py:1: RuntimeWarning: invalid value encountered in log
#   y2 = np.log(y)

# %% [markdown]
# * plot the transformed time series

# %%
plt.plot(x, y2)

# %% [markdown]
# * Apply the function `'ADF_Stationarity_Test'` to find out whether the transformed timeseries is stationary.

# %%
y2 = y2[~np.isnan(y2)]

# %%
ADF_Stationarity_Test(y2, 0.05)
# Out:
# Pvalue 0.028977018708496987 is under sig level 0.05, reject null hypothesis that timeseries is non stationary.
